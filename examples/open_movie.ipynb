# %%
from aicsimageio import AICSImage

# %%
fld = r"U:\MIGRATED\Lab_Members\Daniel_Foust\Data\Flagella\DK1362\2023-06-22_DK1362_2channel\007-009"
fname = r"2023-06-22_DK1362_2channel_008_upper_right.tif"

# %%
help(AICSImage)
# Out:
# Help on class AICSImage in module aicsimageio.aics_image:
#
# class AICSImage(aicsimageio.image_container.ImageContainer)
#  |  AICSImage(image: Union[str, pathlib.Path, numpy.ndarray, dask.array.core.Array, xarray.core.dataarray.DataArray, List[Union[numpy.ndarray, dask.array.core.Array, xarray.core.dataarray.DataArray]], List[Union[str, pathlib.Path]]], reader: Optional[Type[aicsimageio.readers.reader.Reader]] = None, reconstruct_mosaic: bool = True, fs_kwargs: Dict[str, Any] = {}, **kwargs: Any)
#  |
#  |  AICSImage takes microscopy image data types (files or arrays) of varying
#  |  dimensions ("ZYX", "TCZYX", "CYX") and reads them as consistent 5D "TCZYX"
#  |  ("Time-Channel-Z-Y-X") ordered array(s). The data and metadata are lazy
#  |  loaded and can be accessed as needed.
#  |
#  |  Parameters
#  |  ----------
#  |  image: types.ImageLike
#  |      A string, Path, fsspec supported URI, or arraylike to read.
#  |  reader: Optional[Type[Reader]]
# ...
